# %%
# Step 1: Import the necessary libraries
import pandas as pd
import folium

# %%
# Step 2: Load the CSV file into a pandas DataFrame
file_path = 'Colorado_s_Named_Peaks_greater_than_14_000_feet_above_sea_level._20241015.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Display the first few rows to ensure the data has been loaded correctly
df.head(10)
# Out:
#    Rank              Peak  Elevation   Latitude   Longitude
# 0     1        Mt. Elbert      14440  39.117750 -106.445380
# 1     2       Mt. Massive      14421  39.187500 -106.475700
# 2     3       Mt. Harvard      14421  38.924415 -106.320807
# 3     4       Blanca peak      14345  37.577227 -105.485845
# 4     5     La Plata Peak      14336  39.029500 -106.473010
# 5     6  Uncompahgre Peak      14321  38.071665 -107.462186
# 6     7     Crestone Peak      14294  37.966868 -105.585397
# 7     8       Mt. Lincoln      14293  39.351440 -106.111554
# 8     9       Castle Peak      14279  44.087811 -103.722644
# 9    10        Grays Peak      14278  39.661050 -105.784000

# %%
# Step 3: Filter the DataFrame to select relevant columns
columns = ['Rank', 'Peak', 'Elevation', 'Latitude', 'Longitude']
df_filtered = df[columns]

# Check for missing or NaN values in latitude and longitude
df_filtered = df_filtered.dropna(subset=['Latitude', 'Longitude'])

# Ensure that latitude and longitude are in the correct numeric format
df_filtered['Latitude'] = pd.to_numeric(df_filtered['Latitude'], errors='coerce')
df_filtered['Longitude'] = pd.to_numeric(df_filtered['Longitude'], errors='coerce')

# Display the filtered dataframe
df_filtered.head(10)
# Out:
#    Rank              Peak  Elevation   Latitude   Longitude
# 0     1        Mt. Elbert      14440  39.117750 -106.445380
# 1     2       Mt. Massive      14421  39.187500 -106.475700
# 2     3       Mt. Harvard      14421  38.924415 -106.320807
# 3     4       Blanca peak      14345  37.577227 -105.485845
# 4     5     La Plata Peak      14336  39.029500 -106.473010
# 5     6  Uncompahgre Peak      14321  38.071665 -107.462186
# 6     7     Crestone Peak      14294  37.966868 -105.585397
# 7     8       Mt. Lincoln      14293  39.351440 -106.111554
# 8     9       Castle Peak      14279  44.087811 -103.722644
# 9    10        Grays Peak      14278  39.661050 -105.784000

# %%
# Step 4: Create a Folium map centered on Colorado using an average latitude and longitude
colorado_map = folium.Map(location=[38.9972, -105.5478], zoom_start=7)  # Adjust zoom and location if needed

# Step 5: Add markers for each peak
for idx, row in df_filtered.iterrows():
    # Extract peak information
    rank = row['Rank']
    peak_name = row['Peak']
    elevation = row['Elevation']
    latitude = row['Latitude']
    longitude = row['Longitude']
    
    # Create the popup content
    popup_content = (
        f"<b>Rank:</b> {rank}<br>"
        f"<b>Peak:</b> {peak_name}<br>"
        f"<b>Elevation:</b> {elevation} feet<br>"
    )
    
    # Add a marker for the peak
    folium.Marker(
        location=[latitude, longitude],
        popup=folium.Popup(popup_content, max_width=250),
        icon=folium.Icon(color='green', icon='mountain', prefix='fa')
    ).add_to(colorado_map)

# Step 6: Display the map
colorado_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c04c2dd46cb3237b38251c0f82bec71e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c04c2dd46cb3237b38251c0f82bec71e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c04c2dd46cb3237b38251c0f82bec71e = L.map(
#                 &quot;map_c04c2dd46cb3237b38251c0f82bec71e&quot;,
#                 {
#                     center: [38.9972, -105.5478],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c18d1bf13fcebadbcc217e177e85c67b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c18d1bf13fcebadbcc217e177e85c67b.addTo(map_c04c2dd46cb3237b38251c0f82bec71e);
#
#
#             var marker_0a3817942872c25ff63d9ea47baa9e93 = L.marker(
#                 [39.11775, -106.44538],
#                 {}
#             ).addTo(map_c04c2dd46cb3237b38251c0f82bec71e);
#
#
#             var icon_614f306a7bc8140ee4575db2848afd0a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;mountain&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0a3817942872c25ff63d9ea47baa9e93.setIcon(icon_614f306a7bc8140ee4575db2848afd0a);
#
#
#         var popup_9be86e08715795e0a173e08c2ae2a193 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_34e5bd9f9350b6c1c9a7e2437cf9754e = $(`&lt;div id=&quot;html_34e5bd9f9350b6c1c9a7e2437cf9754e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rank:&lt;/b&gt; 1&lt;br&gt;&lt;b&gt;Peak:&lt;/b&gt; Mt. Elbert&lt;br&gt;&lt;b&gt;Elevation:&lt;/b&gt; 14440 feet&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_9be86e08715795e0a173e08c2ae2a193.setContent(html_34e5bd9f9350b6c1c9a7e2437cf9754e);
#
#
#
#         marker_0a3817942872c25ff63d9ea47baa9e93.bindPopup(popup_9be86e08715795e0a173e08c2ae2a193)
#         ;
#
#
#
#
#             var marker_4fd72158cd76586e7db04277dc6ae05b = L.marker(
#                 [39.1875, -106.4757],
#                 {}
#             ).addTo(map_c04c2dd46cb3237b38251c0f82bec71e);
#
#
#             var icon_a24dbd6755f4493d3295039de1a908f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;mountain&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4fd72158cd76586e7db04277dc6ae05b.setIcon(icon_a24dbd6755f4493d3295039de1a908f7);
#
#
#         var popup_7c955adc3e74fe717242cb85690259d7 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_00d59f25b1b7a0375372fa9361949440 = $(`&lt;div id=&quot;html_00d59f25b1b7a0375372fa9361949440&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rank:&lt;/b&gt; 2&lt;br&gt;&lt;b&gt;Peak:&lt;/b&gt; Mt. Massive&lt;br&gt;&lt;b&gt;Elevation:&lt;/b&gt; 14421 feet&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_7c955adc3e74fe717242cb85690259d7.setContent(html_00d59f25b1b7a0375372fa9361949440);
#
#
#
#         marker_4fd72158cd76586e7db04277dc6ae05b.bindPopup(popup_7c955adc3e74fe717242cb85690259d7)
#         ;
#
#
#
#
#             var marker_2e5b9a4863eadba96d8dc376d1d2aef5 = L.marker(
#                 [38.9244148, -106.3208069],
#                 {}
#             ).addTo(map_c04c2dd46cb3237b38251c0f82bec71e);
#
#
#             var icon_700860cf24bc5e4702778dd5ba17100d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;mountain&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2e5b9a4863eadba96d8dc376d1d2aef5.setIcon(icon_700860cf24bc5e4702778dd5ba17100d);
#
#
#         var popup_9d307b2aa86fcd12e8ab252e5920753c = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_23d3efd6f4cdebcb71ec95cf9da0e1ef = $(`&lt;div id=&quot;html_23d3efd6f4cdebcb71ec95cf9da0e1ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rank:&lt;/b&gt; 3&lt;br&gt;&lt;b&gt;Peak:&lt;/b&gt; Mt. Harvard&lt;br&gt;&lt;b&gt;Elevation:&lt;/b&gt; 14421 feet&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_9d307b2aa86fcd12e8ab252e5920753c.setContent(html_23d3efd6f4cdebcb71ec95cf9da0e1ef);
#
#
#
#         marker_2e5b9a4863eadba96d8dc376d1d2aef5.bindPopup(popup_9d307b2aa86fcd12e8ab252e5920753c)
#         ;
#
#
#
#
#             var marker_24cae38b99b8ceb2f1c84d7eccfd2d76 = L.marker(
#                 [37.5772269, -105.4858447],
#                 {}

# %%
# Step 7: Save the map to an HTML file
colorado_map.save("colorado_14K_peaks_map.html")
